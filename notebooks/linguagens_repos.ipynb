# %% [markdown]
# ### Conhecendo a Requests

# %% [markdown]
# Primeira Requisição

# %%
import requests

# %%
r =requests.get('https://api.github.com/events')

# %%
'''
O status code tem a finalidade de indicar se a requisição foi aceita e concluída com sucesso, ou, 
por outro lado, se ocorreu algum erro e a requisição foi rejeitada.
'''
r.status_code
# Out:
# 200

# %%
'''
Além disso, podemos acessar outras informações, como a URL que foi utilizada para realizar a requisição. 
Para isso, podemos utilizar r.url. A URL retornará os eventos que estavam ocorrendo no GitHub.
'''
r.url
# Out:
# 'https://api.github.com/events'

# %%
'''
É fundamental  entendermos como acessar o conteúdo da URL, isto é, o conteúdo que requisitamos.
Existem duas opções para fazer isso:

Usando o r.text

Este comando traz todo o conteúdo que vimos anteriormente no navegador em uma string, 
por isso temos aspas simples envolvendo o conteúdo.

'''
r.text
# Out:
# '[{"id":"51292241123","type":"PushEvent","actor":{"id":23319266,"login":"SHLEM666","display_login":"SHLEM666","gravatar_id":"","url":"https://api.github.com/users/SHLEM666","avatar_url":"https://avatars.githubusercontent.com/u/23319266?"},"repo":{"id":612524401,"name":"SHLEM666/Userscripts","url":"https://api.github.com/repos/SHLEM666/Userscripts"},"payload":{"repository_id":612524401,"push_id":25095005502,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"d03b60528c9ce167b3dd74813b390b5888d4ca66","before":"b11fc7ed97c85cb491ad7f52c8b9362f1524a58e","commits":[{"sha":"d03b60528c9ce167b3dd74813b390b5888d4ca66","author":{"email":"shlem666@yandex.ru","name":"SHLEM666"},"message":"Update Mathprofi.js","distinct":true,"url":"https://api.github.com/repos/SHLEM666/Userscripts/commits/d03b60528c9ce167b3dd74813b390b5888d4ca66"}]},"public":true,"created_at":"2025-06-24T18:48:13Z"},{"id":"51292241204","type":"PullRequestReviewCommentEvent","actor":{"id":136622811,"login":"coderabbitai[bo
# ...

# %%
'''
Outra forma de acessar  o conteúdo que estamos visitando:

2) Usando o r.json(), que traz o conteúdo no formato de JSON.
'''

r.json()
# Out:
# [{'id': '51292241123',
#   'type': 'PushEvent',
#   'actor': {'id': 23319266,
#    'login': 'SHLEM666',
#    'display_login': 'SHLEM666',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SHLEM666',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23319266?'},
#   'repo': {'id': 612524401,
#    'name': 'SHLEM666/Userscripts',
#    'url': 'https://api.github.com/repos/SHLEM666/Userscripts'},
#   'payload': {'repository_id': 612524401,
#    'push_id': 25095005502,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd03b60528c9ce167b3dd74813b390b5888d4ca66',
#    'before': 'b11fc7ed97c85cb491ad7f52c8b9362f1524a58e',
#    'commits': [{'sha': 'd03b60528c9ce167b3dd74813b390b5888d4ca66',
#      'author': {'email': 'shlem666@yandex.ru', 'name': 'SHLEM666'},
#      'message': 'Update Mathprofi.js',
#      'distinct': True,
# ...

# %%
'''
"Utilizando outro endpoint" do VSCode.
'''
r = requests.get('https://api.github.com/versions')

# %%
'''
Testanto se a requisição deu certo
'''
r.status_code
# Out:
# 200

# %%
'''
Visualizando o conteudo da resposta em formato JSON
'''
r.json()
# Out:
# ['2022-11-28']

# %%
'''
Exercício Alura

Faça uma requisição GET à API do Github para obter as informações do perfil de um usuário específico. Para isso, utilize a biblioteca Requests do Python e a URL https://api.github.com/users/{username}, substituindo {username} pelo nome de usuário desejado.

Com o objeto response retornado pela requisição, imprima na tela as seguintes informações sobre a requisição:

status code da requisição, para analisar se foi bem sucedida ou não;
conteúdo da requisição, para conferir se os dados de usuário vieram corretamente;
URL da requisição feita, para garantir que a url utilizada na requisição foi a correta.
Após conferir isso, analise novamente o conteúdo retornado pela requisição e imprima na tela apenas as seguintes informações sobre a pessoa usuária em questão:

Nome
Nome de usuário
Número de repositórios públicos
Data de criação da conta no GitHub


'''


r = requests.get('https://api.github.com/users')

# %%
r.text
# Out:
# '[{"login":"mojombo","id":1,"node_id":"MDQ6VXNlcjE=","avatar_url":"https://avatars.githubusercontent.com/u/1?v=4","gravatar_id":"","url":"https://api.github.com/users/mojombo","html_url":"https://github.com/mojombo","followers_url":"https://api.github.com/users/mojombo/followers","following_url":"https://api.github.com/users/mojombo/following{/other_user}","gists_url":"https://api.github.com/users/mojombo/gists{/gist_id}","starred_url":"https://api.github.com/users/mojombo/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/mojombo/subscriptions","organizations_url":"https://api.github.com/users/mojombo/orgs","repos_url":"https://api.github.com/users/mojombo/repos","events_url":"https://api.github.com/users/mojombo/events{/privacy}","received_events_url":"https://api.github.com/users/mojombo/received_events","type":"User","user_view_type":"public","site_admin":false},{"login":"defunkt","id":2,"node_id":"MDQ6VXNlcjI=","avatar_url":"https://avatars.githubuserconte
# ...

# %%
request_user = requests.get('https://api.github.com/users/mojombo')

# %%
# STATUS CODE
request_user.status_code
# Out:
# 200

# %%
# Conteúdo da requisição
request_user.json()
# Out:
# {'login': 'mojombo',
#  'id': 1,
#  'node_id': 'MDQ6VXNlcjE=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/1?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/mojombo',
#  'html_url': 'https://github.com/mojombo',
#  'followers_url': 'https://api.github.com/users/mojombo/followers',
#  'following_url': 'https://api.github.com/users/mojombo/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/mojombo/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/mojombo/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/mojombo/subscriptions',
#  'organizations_url': 'https://api.github.com/users/mojombo/orgs',
#  'repos_url': 'https://api.github.com/users/mojombo/repos',
#  'events_url': 'https://api.github.com/users/mojombo/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/mojombo/received_events',
#  'type': 'User',
#  'user_view_type': 'public',
#  'site_admin': False,
# ...

# %%
#  1 - Nome
request_user.json()['name']
# Out:
# 'Tom Preston-Werner'

# %%
# 2 - Nome de usuário

request_user.json()['login']
# Out:
# 'mojombo'

# %%
# 3 - Número de repositórios públicos

request_user.json()['public_repos']
# Out:
# 66

# %%
# 4 - Data de criação da conta no GitHub
request_user.json()['created_at']
# Out:
# '2007-10-20T05:24:19Z'

# %% [markdown]
# ### Obtendo dados do projeto

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
# URL base da API
api_base_url = 'https://api.github.com'

# Uername especifico que vou pegar da URL
owner = 'amzn' 

#URL completa
url = f'{api_base_url}/users/{owner}/repos'

# %%
#Antes de executar esse código, adicionaremos uma célula entre a 
# do response e das variáveis anteriores para visualizarmos como 
# ficou essa URL completa
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
# Requisicao com url completae e header (versao da API)
response = requests.get(url,headers=headers)

# %%
# Código de retorno da requisicao
response.status_code
# Out:
# 200

# %%
'''

Se o JSON da resposta for um objeto (com {}) ele retorna um dict.

Se for um array (com []), ele retorna uma list.

Se for um valor simples (ex: número, true, null), 
ele retorna o tipo Python equivalente (int, float, bool, None, etc).

'''
# Out:
# '\n\nSe o JSON da resposta for um objeto (com {}) ele retorna um dict.\n\nSe for um array (com []), ele retorna uma list.\n\nSe for um valor simples (ex: número, true, null), \nele retorna o tipo Python equivalente (int, float, bool, None, etc).\n\n'

# %%
# Tamanho da REquisicao

tamanho = len(response.json())

tamanho
# Out:
# 30

# %% [markdown]
# ### Autenticação

# %% [markdown]
# ##### Solicitações autenticadas têm um limite de taxa mais alto. Quando um usuário faz uma solicitação autenticada, ele fornece credenciais que comprovam sua identidade, o que permite que a API confine nele e lhe conceda acesso a recursos e funcionalidades adicionais.
#
# ##### Além disso, a maioria das APIs estabelece limites para o número de solicitações que o usuário pode fazer em um determinado período de tempo, conhecido como limite de taxa (rate limit). Esse mecanismo ajuda a proteger os servidores contra sobrecarga, uso abusivo ou ataques, garantindo que os recursos da API sejam distribuídos de forma justa entre todos os usuários.
#
# ##### Quando um usuário faz solicitações autenticadas, a API geralmente  permite que ele faça mais solicitações em um determinado período de tempo, devido à maior confiança e credibilidade que a autenticação fornece.

# %%
# Criei no Developer Settings no GitHub
access_token = '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'

# Documentacao do github diz que tem que ser como o debaixo:
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# #### Paginando os repositórios

# %%
'''
Aguardamos um pouco para tudo ser executado. Em seguida, voltaremos 
à célula onde definimos a URL com todos os endpoints que utilizamos 
para extrair dados dos repositórios. Nessa célula, copiaremos as 
variáveis api_base_url, owner e url e colaremos em uma célula mais
abaixo, na seção Paginando os repositórios, apenas para termos um 
acesso mais fácil a elas.
'''

api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
'''
Na primeira linha, estamos definindo uma lista vazia com o nome de 
repos_list. Essa lista será utilizada para armazenar cada uma das 
páginas de onde extrairemos os dados com seus respectivos 
repositórios.
Logo abaixo dessa definição da lista, temos um laço for. 
Precisaremos desse laço porque, como sabemos, há cinco páginas que 
precisamos percorrer.
'''

repos_list = []
for page_num in range(1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
'''
Analisando o conteúdo da nossa lista, notaremos que ela é uma lista de 
sublistas, e cada uma dessas sublistas é composta por vários 
dicionários. Cada sublista existente na repos_list corresponde a 
uma das páginas de repositórios do GitHub da Amazon, e cada
dicionário existente nessas sublistas são os repositórios existentes
em cada uma das páginas. 
'''

repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
''' 
Na célula seguinte, se escrevermos len(repos_list) para verificarmos
o tamanho da nossa lista, conferimos que ela tem o tamanho 5, 
que é a mesma quantidade de páginas de repositórios que temos no 
GitHub da Amazon.

'''
# Tamanho de SUBLISTAS = Qtde de páginas de repositorios na pagina da amazon
len(repos_list)
# Out:
# 5

# %%
# Tamanho da primeira páginas que temos
len(repos_list[0])
# Out:
# 30

# %% [markdown]
# ### Transformando os dados

# %% [markdown]
# ##### Nome dos repositórios

# %%
''' 
Uma vez que selecionamos a página, podemos selecionar o repositório. 
Então, basta incluir mais um par de colchetes e colocar o índice do 
repositório
'''
repos_list[0][2]['name']
# Out:
# 'ads-pao-amznjs-gtm-server-side-template'

# %%
''' 
Agora, vamos percorrer toda a lista repos_list para pegar apenas os 
nomes e salvá-los em uma lista.
'''
repos_name = []
for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])

# %%
#  visualizar apenas os 10 primeiros nomes extraídos dos repositórios

repos_name[:10]
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-server-side-template',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool']

# %%
# Para garantir que conseguimos extrair os nomes de todos os 
# repositórios existentes, podemos conferir o tamanho da lista 
# repos_name

len(repos_name)
# Out:
# 150

# %% [markdown]
# #### Linguagens dos repositórios

# %%
repos_language = []
for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])

# %%
len(repos_language)
# Out:
# 150

# %%
repos_language
# Out:
# [None,
#  'Jupyter Notebook',
#  'Smarty',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Ruby',
#  'PHP',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  None,
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Kotlin',
#  'Python',
#  'Python',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Java',
#  'Kotlin',
# ...

# %% [markdown]
# ### Criando um DataFrame

# %%
import pandas as pd

# %%
# Criando o DAtaFrame e armazenando na variável dados_amz
dados_amz = pd.DataFrame()

# %%
# Preenchendo e criando a primeira coluna nele

dados_amz['repository_name'] = repos_name

# %%
# Criando coluna de languages

dados_amz['language'] = repos_language

# %%
# Visualizando como está

dados_amz
# Out:
#                              repository_name          language
# 0                                    .github              None
# 1                    ads-advanced-tools-docs  Jupyter Notebook
# 2    ads-pao-amznjs-gtm-server-side-template            Smarty
# 3                ads-pao-amznjs-gtm-template            Smarty
# 4                                 alexa-coho        JavaScript
# ..                                       ...               ...
# 145                             sparse-vqvae            Python
# 146                               ss-aga-kgc            Python
# 147                          sto-transformer            Python
# 148      supply-chain-simulation-environment            Python
# 149               tiny-attribution-generator        TypeScript
#
# [150 rows x 2 columns]

# %% [markdown]
# ### Salvando o DataFrame

# %%
# Criando arquivo csv com o método .csv do pandas
dados_amz.to_csv('amazon.csv')

# %% [markdown]
# ### Armazenando os dados

# %% [markdown]
# #### Criando repositório com POST

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

url
# Out:
# 'https://api.github.com/user/repos'

# %%
''' 
Como precisamos que outros times tenham acesso a esse repositório, 
é importante que ele seja público. 
Por isso, passamos private: False.
'''
data = {
    'name': 'linguagens-utilizadas',
    'description': 'Repositorio com as linguagens de prog da Amazon',
    'private': False
}

# criação do nosso repositório na nossa conta pessoal. 

response = requests.post(url, json=data, headers=headers)

# verificação da resposta do servidor, status code
response.status_code


'''
 Passamos os headers que possuem o token de autenticação 
 e a versão da API que queremos utilizar. 
 Ou seja, headers igual a headers

'''
# Out:
# '\n Passamos os headers que possuem o token de autenticação \n e a versão da API que queremos utilizar. \n Ou seja, headers igual a headers\n\n'

# %% [markdown]
# ### Formato do arquivo

# %%
import base64

# %%
with open('amazon.csv','rb')  as  file:
    file_content = file.read()

encoded_content = base64.b64encode(file_content)

# %% [markdown]
# ### Upload de arquivo com PUT

# %%
''' 
Para fazer o upload do arquivo no repositório, precisamos utilizar 
outros endpoints que já definimos no notebook do Google Colab. 
Vamos conferir:

'''

api_base_url = 'https://api.github.com'
username = 'juanluistr38'
repo = 'linguagens-utilizadas'
path = 'amazon.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/juanluistr38/linguagens-utilizadas/contents/amazon.csv'

# %%
'''
Agora, na próxima célula, precisamos definir um dicionário com 
as informações que queremos passar no momento de fazer o upload 
desse arquivo. Da mesma forma que definimos um 
dicionário no momento de criar um repositório.
Vamos chamar novamente esse dicionário de data, ou seja,
 
'''


data = {
    'message': 'Adicionando um novo arquivo',
    'content': encoded_content.decode('utf-8')
}

response = requests.put(url, json=data, headers=headers)
response.status_code
# Out:
# 422
